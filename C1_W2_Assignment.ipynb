# %% [markdown]
# # Assignment 2: Naive Bayes
# Welcome to week two of this specialization. You will learn about Naive Bayes. Concretely, you will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Train a naive bayes model on a sentiment analysis task
# * Test using your model
# * Compute ratios of positive words to negative words
# * Do some error analysis
# * Predict on your own tweet
#
# You may already be familiar with Naive Bayes and its justification in terms of conditional probabilities and independence.
# * In this week's lectures and assignments we used the ratio of probabilities between positive and negative sentiment.
# * This approach gives us simpler formulas for these 2-way classification tasks.
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/classification-vector-spaces-in-nlp/supplement/YLuAg/h-ow-to-refresh-your-workspace).
#
# Lets get started!
#
# Load the cell below to import some packages.
# You  may want to browse the documentation of unfamiliar libraries and functions.

# %% [markdown]
# ## Table of Contents
#
# - [Importing Functions and Data](#0)
# - [1 - Process the Data](#1)
#     - [1.1 - Implementing your Helper Functions](#1-1)
#         - [Exercise 1 - count_tweets (UNQ_C1)](#ex-1)
# - [2 - Train your Model using Naive Bayes](#2)
#     - [Exercise 2 - train_naive_bayes (UNQ_C2)](#ex-2)
# - [3 - Test your Naive Bayes](#3)
#     - [Exercise 3 - naive_bayes_predict  (UNQ_C4)](#ex-3)
#     - [Exercise 4 - test_naive_bayes (UNQ_C6)](#ex-4)
# - [4 - Filter words by Ratio of Positive to Negative Counts](#4)
#     - [Exercise 5 - get_ratio (UNQ_C8)](#ex-5)
#     - [Exercise 6 - get_words_by_threshold (UNQ_C9)](#ex-6)
# - [5 - Error Analysis](#5)
# - [6 - Predict with your own Tweet](#6)

# %% [markdown]
# <a name='0'></a>
# ## Importing Functions and Data

# %%
from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd
import w2_unittest

nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# If you are running this notebook in your local computer,
# don't forget to download the tweeter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# <a name='1'></a>
# ## 1 - Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet` that does this for you.

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"

# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Implementing your Helper Functions
#
# To help you train your naive bayes model, you will need to compute a dictionary where the keys are a tuple (word, label) and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a lookup helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2,
#     ("happi", 1) : 1,
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# <a name='ex-1'></a>
# ### Exercise 1 - count_tweets
# Create a function `count_tweets` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.</li>
#     <li>You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.</li>
#     <li>Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.</li>
#     <li>Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.</li>
# </ul>
# </p>

# %%
# UNQ_C1 GRADED FUNCTION: count_tweets

def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    ### START CODE HERE ###
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # define the key, which is the word and label tuple
            pair = (word, y)
            
            # if the key exists in the dictionary, increment the count
            if pair in result:
                result[pair] += 1

            # else, if the key is new, add it to the dictionary and set the count to 1
            else:
                result[pair] = 1
    ### END CODE HERE ###
    return result

# %%
# Testing your function

result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# **Expected Output**: {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %%
# Test your function
w2_unittest.test_count_tweets(count_tweets)
# Out:
#  All tests passed

# %% [markdown]
# <a name='2'></a>
# ## 2 - Train your Model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses
freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - train_naive_bayes
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$, and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)$.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    # calculate V, the number of unique words in the vocabulary
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)    

    # calculate N_pos, N_neg, V_pos, V_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        if pair[1] > 0:
            N_pos += freqs[pair]
        else:
            N_neg += freqs[pair]
    
    # Calculate D, the number of documents
    D = len(train_y)

    # Calculate D_pos, the number of positive documents
    D_pos = sum(train_y)

    # Calculate D_neg, the number of negative documents
    D_neg = D - D_pos

    # Calculate logprior
    logprior = np.log(D_pos) - np.log(D_neg)
    
    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = freqs.get((word, 1), 0)
        freq_neg = freqs.get((word, 0), 0)

        # calculate the probability
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        # calculate the log likelihood
        loglikelihood[word] = np.log(p_w_pos / p_w_neg)

    return logprior, loglikelihood

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 9165

# %% [markdown]
# **Expected Output**:
#
# 0.0
#
# 9165

# %%
# Test your function
w2_unittest.test_train_naive_bayes(train_naive_bayes, freqs, train_x, train_y)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Test your Naive Bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# <a name='ex-3'></a>
# ### Exercise 3 - naive_bayes_predict
# Implement `naive_bayes_predict`.
#
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
# UNQ_C4 GRADED FUNCTION: naive_bayes_predict

def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    ### START CODE HERE ###
    # process the tweet to get a list of words
    word_l = process_tweet(tweet)

    # initialize probability to zero
    p = 0

    # add the logprior
    p += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood[word]

    ### END CODE HERE ###

    return p

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.5577981920239676

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.55
# - The sentiment is positive.

# %%
# Test your function
w2_unittest.test_naive_bayes_predict(naive_bayes_predict)
# Out:
#  All tests passed

# %%
# Experiment with your own tweet.
my_tweet = 'He laughed.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is -0.1649684057171359

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4 - test_naive_bayes
# Implement test_naive_bayes.
#
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
# UNQ_C6 GRADED FUNCTION: test_naive_bayes

def test_naive_bayes(test_x, test_y, logprior, loglikelihood, naive_bayes_predict=naive_bayes_predict):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  # return this properly

    ### START CODE HERE ###
    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            # the predicted class is 1
            y_hat_i = 1
        else:
            # otherwise the predicted class is 0
            y_hat_i = 0

        # append the predicted class to the list y_hats
        y_hats.append(y_hat_i)

    # error is the average of the absolute values of the differences between y_hats and test_y
    error = np.mean(np.abs(np.array(y_hats) - np.array(test_y)))

    # Accuracy is 1 minus the error
    accuracy = 1- error

    ### END CODE HERE ###

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9955

# %% [markdown]
# **Expected Accuracy**:
#
# `Naive Bayes accuracy = 0.9955`

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 2.14
# I am bad -> -1.31
# this movie should have been great. -> 2.12
# great -> 2.13
# great great -> 4.26
# great great great -> 6.39
# great great great great -> 8.52

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.14
# - I am bad -> -1.31
# - this movie should have been great. -> 2.12
# - great -> 2.13
# - great great -> 4.26
# - great great great -> 6.39
# - great great great great -> 8.52

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# -8.837351738825648

# %%
# Test your function
w2_unittest.unittest_test_naive_bayes(test_naive_bayes, test_x, test_y)
# Out:
#  All tests passed

# %% [markdown]
# <a name='4'></a>
# ## 4 - Filter words by Ratio of Positive to Negative Counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# <a name='ex-5'></a>
# ### Exercise 5 - get_ratio
# Implement get_ratio.
#
# - Given the freqs dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
# UNQ_C8 GRADED FUNCTION: get_ratio

def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    ### START CODE HERE ###
    # use lookup() to find positive counts for the word (denoted by the integer 1)
    pos_neg_ratio['positive'] = lookup(freqs,word, 1)
    
    # use lookup() to find negative counts for the word (denoted by integer 0)
    pos_neg_ratio['negative'] = lookup(freqs, word, 0)
    
    #if pos_neg_ratio['negative'] != 0:
        #pos_neg_ratio['ratio'] = pos_neg_ratio['positive'] / pos_neg_ratio['negative']
    
    # calculate the ratio of positive to negative counts for the word
    pos_neg_ratio['ratio'] = (pos_neg_ratio['positive']+1) / (pos_neg_ratio['negative']+1)
    ### END CODE HERE ###
    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 162, 'negative': 18, 'ratio': 8.578947368421053}

# %%
# Test your function
w2_unittest.test_get_ratio(get_ratio, freqs)
# Out:
#  All tests passed

# %% [markdown]
# <a name='ex-6'></a>
# ### Exercise 6 - get_words_by_threshold
# Implement get_words_by_threshold(freqs,label,threshold)
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append the `get_ratio` dictionary inside another dictinoary, where the key is the word, and the value is the dictionary `pos_neg_ratio` that is returned by the `get_ratio` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.524}
# }
# ```

# %%
# UNQ_C9 GRADED FUNCTION: get_words_by_threshold

def get_words_by_threshold(freqs, label, threshold, get_ratio=get_ratio):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_list: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    ### START CODE HERE ###
    for key in freqs.keys():
        word, _ = key

        # get the positive/negative ratio for a word
        pos_neg_ratio = get_ratio(freqs,word)

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
        
            # Add the pos_neg_ratio to the dictionary
            word_list[word] = pos_neg_ratio

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
        
            # Add the pos_neg_ratio to the dictionary
            word_list[word] =pos_neg_ratio

        # otherwise, do not include this word in the list (do nothing)

    ### END CODE HERE ###
    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {'followfriday': {'positive': 23, 'negative': 0, 'ratio': 0.0},
#  'engag': {'positive': 7, 'negative': 0, 'ratio': 0.0},
#  '02392441234': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'assist': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yeaaah': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yipppi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'accnt': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'verifi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'rqst': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'succeed': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tick': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'irresist': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'flipkartfashionfriday': {'positive': 16, 'negative': 0, 'ratio': 0.0},
#  'lwwf': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bayan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  ':D': {'positive': 523, 'negative': 0, 'ratio': 0.0},
#  'mischiev': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'etl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'layer': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'in-hous': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wareh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'katamari': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'impli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  ':p': {'positive': 104, 'negative': 0, 'ratio': 0.0},
#  'influenc': {'positive': 16, 'negative': 0, 'ratio': 0.0},
#  'juici': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'junior': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'triathlet': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gatorad': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'print': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  ':-)': {'positive': 552, 'negative': 0, 'ratio': 0.0},
#  "friend'": {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'yummm': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nostalgia': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tb': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ku': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'conflict': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  "here'": {'positive': 20, 'negative': 0, 'ratio': 0.0},
#  'liv': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'fm': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'dope': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'penthous': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'obv': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gobigorgohom': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'youth': {'positive': 14, 'negative': 0, 'ratio': 0.0},
#  '💅': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'spiritu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ritual': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'népal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'line-up': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'sarah': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'bitsy@bitdefender.com': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hatessuc': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '32429': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cumshot': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nsn_supplement': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'press': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'distribut': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pressreleas': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'newsdistribut': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bam': {'positive': 44, 'negative': 0, 'ratio': 0.0},
#  'warsaw': {'positive': 44, 'negative': 0, 'ratio': 0.0},
#  'x46': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'documentari': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'earthl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'letsgetmessi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'soundtrack': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'shout': {'positive': 11, 'negative': 0, 'ratio': 0.0},
#  'twitch': {'positive': 7, 'negative': 0, 'ratio': 0.0},
#  'gameplay': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  ';)': {'positive': 22, 'negative': 0, 'ratio': 0.0},
#  'etsi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'boxroomcraft': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'recharg': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'speech': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'canal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dasvidaniya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'scout': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wlan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pro': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'lollipop': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '🍭': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nez': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'agnezmo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'oley': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'stronger': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'misti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'woohoo': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'mka': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'stat': {'positive': 51, 'negative': 0, 'ratio': 0.0},
#  'happybirthdayemilybett': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'timezon': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'manila_bro': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'chosen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x45': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hushedcallwithfraydo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hushedpinwithsammi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'scope': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  't-shirt': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'haw': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'phela': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'princ': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tyler': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hipster': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'marti': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'kahfi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ohmyg': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yaya': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'dub': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ig': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'gondooo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'moo': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'tologooo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'physiotherapi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x43': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'advic': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'treviso': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'oven': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'roast': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'garlic': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'oliv': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'centuri': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tuna': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'atchya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'heheheh': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'volta': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'funcionar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jailbroken': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '34': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'leia': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hologram': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'r2d2': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'obi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ucl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'arsen': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '🚂': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dewsburi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'dew': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yorkshir': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '430': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '9:25': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'strang': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'masaantoday': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'a4': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'shweta': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tripathi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'kurta': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'larri': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'enn': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'warmup': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '15th': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'bath': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'dum': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'andar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ram': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sampath': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sona': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mohapatra': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'samantha': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tulan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'razi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '16.20': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'giveitup': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ga': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'subsidi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x42': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'lmaoo': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'throwback': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'outli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cheung': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'chau': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mui': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'kfckitchentour': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'cusp': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'reward': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'arummzz': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'yogyakarta': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'jeep': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'instamood': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'pretend': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'winner': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'cheesydelight': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'contest': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'wd': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'engin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'blog': {'positive': 27, 'negative': 0, 'ratio': 0.0},
#  '☆': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'triangl': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'northern': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'smthng': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'xoxo': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'jaann': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'topnewfollow': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'pirouett': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'moos': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'philli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x41': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'flaw': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'negat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fav': {'positive': 11, 'negative': 0, 'ratio': 0.0},
#  'nirvana': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'winehous': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tomhiddleston': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'elizabetholsen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yaytheylookgreat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'vid': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  'itti': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'bitti': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'teeni': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'bikini': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'xfile': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fabul': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'fantast': {'positive': 9, 'negative': 0, 'ratio': 0.0},
#  'jb': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nighti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'foundri': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sens': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'ef': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'woot': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'parkshar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gloucestershir': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'aaaahhh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'reliev': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  "how'r": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'arbeloa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '17': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'uncount': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'unlimit': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'teamposit': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'rita': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  "we'd": {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'x40': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sethi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'exe': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'skeem': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'saam': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'izzat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wese': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'khawateen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sath': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'kar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'deya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tee': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'mclaren': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'squar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'enix': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bissmillah': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'socent': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'startup': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'arnd': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'complic': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sport': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'rakyat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ourdaughtersourprid': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'mypapamyprid': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'papa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'kha': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'atleast': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'x39': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  "lassi'": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  "monty'": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'suspect': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'kepler': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  '452b': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'chalna': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hazel': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pta': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'okayi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'doc': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'splendid': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'amount': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nigeria': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'thaaank': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'puhon': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'happinesss': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tnc': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'prior': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '2:22': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yuna': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'tamesid': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'scouser': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'zoe': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'samee': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'edgar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'abe': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x38': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dreamili': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pout': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'quacketyquack': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'phil': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'del': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'rodder': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'newest': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gamejam': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'irish': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'literatur': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'inaccess': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  "kareena'": {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'braindot': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  'brandi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'carniv': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'men': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  'mask': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'xavier': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'forneret': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jennif': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '50.000': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'coin': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'trish': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wakeup': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'besid': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'dirti': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'lmaooo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '😤': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'inspir': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'twoof': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'gr8': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wkend': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'cheltenham': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'kale': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'crisp': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x37': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'worldwid': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'sfvbeta': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'vantast': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'xcylin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bundl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'realisticli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nelson': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mandela': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'recent': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  'chenab': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'flow': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'incredibleindia': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'salmon': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'super-blend': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'youth@bipolaruk.org.uk': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'alma': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mater': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'highschoolday': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'clientvisit': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'christian': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'lizaminnelli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'upcom': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'natur': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pefumeri': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'neal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yard': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'covent': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fback': {'positive': 26, 'negative': 0, 'ratio': 0.0},
#  'indo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'harmo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'americano': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'handshom': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'juga': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hurray': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'exec': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'loryn.good@lincs-chamber.co.uk': {'positive': 1,
#   'negative': 0,
#   'ratio': 0.0},
#  'china': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'homosexu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hyungbot': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'timetunnel': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '1982': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hiii': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'ili': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'domino': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hastili': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pakistani': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x36': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '3point': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dreamteam': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bailey': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'pbb': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  '737gold': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'drank': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wale': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'yippe': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '💟': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  "u'r": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bigot': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'squat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dobar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'musicolog': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'iflix': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bisexu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'minal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'aidzin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'smu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'oval': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'basketbal': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'whahahaha': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'soamaz': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'a5': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'teamr': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'greatli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cinepambata': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mechan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'form': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'sali': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'swisher': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ducktail': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'surreal': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'exposur': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sotw': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jingli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jangli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'loveli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'halesowen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'blackcountryfair': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'assess': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ooz': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'amassiveoverdoseofship': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'chan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gemma': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'orlean': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'geskenya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'obamainkenya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'magicalkenya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'greatkenya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'allgoodthingsk': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'umaru': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'singer': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'label': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'batch': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'princip': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wooftast': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'necessari': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'whatev': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'abstin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'relentlessli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'approxim': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'oldschool': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'runescap': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'daaay': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jumma_mubarik': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'frnd': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'stay_bless': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pussycat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pretoria': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fahrinahmad': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tengkuaaronshah': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'eksperimencinta': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tykkäsin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'videosta': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '200sub': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '15e': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'paysafecard': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'lue': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hoodi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'eeep': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sohappyrightnow': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mmm': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'azz-set': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gain': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'valu': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'manthan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tune': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'maxfreshmov': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'loneliest': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tattoo': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'friday.and': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'magnific': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'rashmi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dedic': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'happyfriday': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'rad': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fanart': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fennel': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'journal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'land': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'yesss': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'gomez': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tomlinson': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'payn': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'caradelevingn': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '🌷': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'iamca': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'afti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'goodmorn': {'positive': 7, 'negative': 0, 'ratio': 0.0},
#  'prokabaddi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'koel': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mallick': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'recit': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'anthem': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yournaturallead': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'youngnaturallead': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mon': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  '27juli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cumbria': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'flockstar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'thur': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '30juli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'itv': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sleeptight': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'haveagoodday': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fulli': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'intend': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '>:d': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'teamadmicro': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fridaydownpour': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'rohit': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sheer': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'obama': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'innumer': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'presid': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'shauri': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yako': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'memotohat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  "t'wa": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cabincrew': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'langkawi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fulfil': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  '👉': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  '👈': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'ex-tweleb': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'makeov': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'brilliantli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'happyyi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'birthdaaayyy': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'program': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'career': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'sad': {'positive': 5, 'negative': 100, 'ratio': 0.05},
#  'overwhelmingli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'aha': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'beaut': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '♬': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'deo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'faaabul': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'aluminiumfre': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'stayfresh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'john': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'navig': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'thnk': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'progrmr': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '9am': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'poetri': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'frequentfly': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'londondairi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  ":')": {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'chuckl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'doh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'subscrib': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'stamina': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tweeti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '-->': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'introduc': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'spread': {'positive': 7, 'negative': 0, 'ratio': 0.0},
#  'supa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dupa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dartmoor': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dii': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'smf': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ft': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'stationari': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'specialis': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'thermal': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'survey': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'south': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'scamper': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'chweina': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jotzh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'coat': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'beforehand': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'foh': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'menac': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'admin': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'lukri': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'redid': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'v.ball': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'atm': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'suitcas': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'hang-copi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  "dostoevsky'": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'voucher': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bugatti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'مطعم_هاشم': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'a7la': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bdayt': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mnwreeen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jazz': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'x34': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pbevent': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hq': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yoona': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hairpin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mastership': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'paindo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'await': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'manni': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'brijresid': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '156': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'encompass': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bhk': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '91': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '975-580-': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '444': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'honor': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'curri': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'milano': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  ':-d': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'gass': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'starsquad': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  '⭐': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'utc': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'flume': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'kaytranada': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'alunageorg': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'certainti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'solv': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '👊': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'totem': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'alic': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'checkout': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'goodwynsgoodi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ugh': {'positive': 1, 'negative': 23, 'ratio': 0.043478260869565216},
#  'fade': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'moan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jozi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tix': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'atl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yellow': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'atla': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yein': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'selo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'waiter': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'titl': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'wrip': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'conni': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'crew': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'sweetan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'soprano': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ukrain': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x33': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'olli': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'disney.art': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'elmoprinssi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'salsa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'blogiversari': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bohol': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'briliant': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'annual': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '\U000fe334': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'yeheyi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pinya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'whoooah': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tranc': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'subject': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'jungl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'accommod': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sandroforceo': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'ceo': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  '1month': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  'workinprogress': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'finnigan': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'loyal': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'fotoset': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'reus': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'muntu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gem': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'falco': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'supersmash': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hotnsexi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'friskyfriday': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tissu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hotb': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'classicassur': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'thrill': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'aerial': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'camera': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'oper': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'boom': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ferri': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'central': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'after-work': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'resto': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'drinkt': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'koffi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'a6': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'stargat': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'atlanti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'muaahhh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '🙈': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nagsend': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ulit': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  '🎈': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'legget': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'qui': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'per': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'encourag': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'employ': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'poster': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'sticker': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tablet': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'milo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'aurini': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'juicebro': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pillar': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'boii': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'smashingbook': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bibl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sick': {'positive': 1, 'negative': 32, 'ratio': 0.03125},
#  'lamo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fangirl': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'platon': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'resid': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'servicewithasmil': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bloodlin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'huski': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'obituari': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'goofingaround': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dah': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'bitter': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'anger': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hatr': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'indiffer': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'zach': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ac': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'excel': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'boggl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fatigu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'baareeq': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gamedev': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hobbi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tweenie_fox': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'accessori': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tamang': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hinala': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'niam': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'selfiee': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'lass': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ale': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'feminist': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fought': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'snobbi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mighti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '🔥': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'jog': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'remot': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'newli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ebay': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'disneyinfin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'starwar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'charact': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'preorder': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'starter': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'homi': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'skin': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'chant': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'heeeyyy': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'woah': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  '★': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'phew': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'philippin': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '😀': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '😃': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '😅': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tombraid': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hype': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'thejuiceinthemix': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'rela': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'prioriti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'collaps': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'chaotic': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cosa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '<---': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'alliter': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'oppayaa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'natgeo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'stoke': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'approv': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  "god'": {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'jisung': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nicola': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'brighten': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'helen': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'brian': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'creak': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'abuti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tweetland': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'xma': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'skyblock': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bcaus': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'unniee': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nuka': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'penacova': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'djset': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'kizomba': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'latinhous': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'housemus': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'portug': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tast': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'yer': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'mtn': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mistress': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'saphir': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '4000': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'coconut': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sambal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mussel': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'recip': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'kalin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mixcloud': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sarcasm': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hehe': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  'benson': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'solid': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '16/17': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '°': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '😜': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'maryhick': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'musicbiz': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sheskindahot': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fleekil': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mbalula': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'africa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mexican': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'scar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'donut': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'foiegra': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'stark': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'incred': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'poem': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dale': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jcreport': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'piggin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'botan': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'soap': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'freshli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '3week': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'heal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tobi-bro': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'isp': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cam': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  "masha'allah": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wwat': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'franc': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'yaaay': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'beirut': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'soda': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fuller': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '💓': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'rettweet': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'mvg': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'valuabl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bergerac': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'u21': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'individu': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  "beach'": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'suicid': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'squad': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fond': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'christoph': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'cocki': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'prove': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  "attitude'": {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'improv': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'suggest': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'inde': {'positive': 6, 'negative': 0, 'ratio': 0.0},
#  'intellig': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'home-bas': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fleur': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'readystock_hijabmart': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'idr': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '325.000': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '200.000': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tompolo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'aim': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'buyer': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'particularli': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'mam': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'feytyaz': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'stiffen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ricky_feb': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'grindea': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'courier': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'crypt': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'arma': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'limbo': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'orchard': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'karachi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'accumul': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'maroon': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cocktail': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'mididress': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '0-100': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '1100d': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'auto-focu': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'vein': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'glaze': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pake': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'joim': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'troop': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'mail': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'ladolcevitainluxembourg@hotmail.com': {'positive': 1,
#   'negative': 0,
#   'ratio': 0.0},
#  'prrequest': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'journorequest': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'the_madstork': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'shaun': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'actress': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wick': {'positive': 8, 'negative': 0, 'ratio': 0.0},
#  'hola': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'houston': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'tx': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'jenni': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  "year'": {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'stumbl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'prob.nic': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'choker': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'seouljin': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'photoset': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'sadomasochistsparadis': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wynter': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'outtak': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sadomasochist': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'paradis': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cypher': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'amen': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'x32': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'corner': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'addict': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'owe': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ape': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'saar': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'vers': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'butterfli': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bonu': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'yummmyyi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dosa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'achi': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'bawi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'queenesth': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sharp': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'poldi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cimbom': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bruhhh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'knowledg': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  '1tb': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'depart': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'anz': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'offshor': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'gottolovebank': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'in-shaa-allah': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dua': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'aameen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '4/5': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'coca': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'cola': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'fanta': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'pepsi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sprite': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'all': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sweeeti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  ';-)': {'positive': 4, 'negative': 0, 'ratio': 0.0},
#  'welcometweet': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'setup': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'carpet': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'judgment': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'hypocrit': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'narcissist': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'jumpsuit': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'verg': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'owl': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'constant': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'sia': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'religion': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'bencher': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'porsch': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'paddock': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'budapestgp': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'johnyherbert': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'porschesupercup': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'koyal': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'melodi': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wirh': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'arc': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'x31': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'wolv': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'desir': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'ameen': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'kca': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'votejkt': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  '48id': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'helpinggroupdm': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'dp': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'chick': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'guid': {'positive': 3, 'negative': 0, 'ratio': 0.0},
#  'zonzofox': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'bhaiya': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'patti': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'elabor': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'merdeka': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'palac': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  'plusmil': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'servic': {'positive': 5, 'negative': 0, 'ratio': 0.0},
#  'hahahaa': {'positive': 1, 'negative': 0, 'ratio': 0.0},
#  'nex': {'positive': 2, 'negative': 0, 'ratio': 0.0},
#  ...}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'commun': {'positive': 27, 'negative': 1, 'ratio': 27.0},
#  ':)': {'positive': 2960, 'negative': 2, 'ratio': 1480.0},
#  'friday': {'positive': 91, 'negative': 9, 'ratio': 10.11111111111111},
#  'opportun': {'positive': 17, 'negative': 1, 'ratio': 17.0},
#  'ad': {'positive': 10, 'negative': 1, 'ratio': 10.0},
#  'welcom': {'positive': 54, 'negative': 5, 'ratio': 10.8},
#  'arriv': {'positive': 57, 'negative': 4, 'ratio': 14.25},
#  'appreci': {'positive': 28, 'negative': 2, 'ratio': 14.0},
#  'invit': {'positive': 15, 'negative': 1, 'ratio': 15.0},
#  'glad': {'positive': 41, 'negative': 2, 'ratio': 20.5},
#  'definit': {'positive': 20, 'negative': 2, 'ratio': 10.0},
#  "let'": {'positive': 20, 'negative': 2, 'ratio': 10.0},
#  'goodnight': {'positive': 18, 'negative': 1, 'ratio': 18.0},
#  'info': {'positive': 11, 'negative': 1, 'ratio': 11.0},
#  'ff': {'positive': 40, 'negative': 4, 'ratio': 10.0},
#  'thx': {'positive': 12, 'negative': 1, 'ratio': 12.0},
#  '–': {'positive': 14, 'negative': 1, 'ratio': 14.0},
#  'click': {'positive': 12, 'negative': 1, 'ratio': 12.0},
#  'follback': {'positive': 18, 'negative': 1, 'ratio': 18.0},
#  'coffe': {'positive': 10, 'negative': 1, 'ratio': 10.0},
#  'brilliant': {'positive': 10, 'negative': 1, 'ratio': 10.0}}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like glad, community, arrives, tend to be found in the positive tweets.

# %%
# Test your function
w2_unittest.test_get_words_by_threshold(get_words_by_threshold, freqs)
# Out:
# Wrong number of elements in output dictionary.
# 	Expected: 13.
# 	Got: 6899.
# Wrong output values.
# 	Expected: {':(': {'ratio': 0.000544069640914037}}.
# 	Got: {':(': 0.00027210884353741496}.
# Wrong output values.
# 	Expected: {':-(': {'ratio': 0.002583979328165375}}.
# 	Got: {':-(': 0.0}.
# Wrong output values.
# 	Expected: {'zayniscomingbackonjuli': {'ratio': 0.05}}.
# 	Got: {'zayniscomingbackonjuli': 0.0}.
# Wrong output values.
# 	Expected: {'26': {'ratio': 0.047619047619047616}}.
# 	Got: {'26': 0.0}.
# Wrong output values.
# 	Expected: {'>:(': {'ratio': 0.022727272727272728}}.
# 	Got: {'>:(': 0.0}.
# Wrong output values.
# 	Expected: {'lost': {'ratio': 0.05}}.
# 	Got: {'lost': 0.0}.
# Wrong output values.
# 	Expected: {'♛': {'ratio': 0.004739336492890996}}.
# 	Got: {'♛': 0.0}.
# Wrong output values.
# 	Expected: {'》': {'ratio': 0.004739336492890996}}.
# 	Got: {'》': 0.0}.
# Wrong output values.
# 	Expected: {'beli̇ev': {'ratio': 0.027777777777777776}}.
# 	Got: {'beli̇ev': 0.0}.
# Wrong output values.
# 	Expected: {'wi̇ll': {'ratio': 0.027777777777777776}}.
# 	Got: {'wi̇ll': 0.0}.
# Wrong output values.
# 	Expected: {'justi̇n': {'ratio': 0.027777777777777776}}.
# 	Got: {'justi̇n': 0.0}.
# Wrong output values.
# 	Expected: {'ｓｅｅ': {'ratio': 0.027777777777777776}}.
# 	Got: {'ｓｅｅ': 0.0}.
# Wrong output values.
# 	Expected: {'ｍｅ': {'ratio': 0.027777777777777776}}.
# 	Got: {'ｍｅ': 0.0}.
# Wrong number of elements in output dictionary.
# 	Expected: 24.
# 	Got: 21.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/work/w2_unittest.py in test_get_words_by_threshold(target, freqs)
#     780                 try:
# --> 781                     assert np.isclose(result[key][sec_key], sec_value)
#     782                     successful_cases += 1
#
# KeyError: 'followfriday'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-e4897f59a4e5> in <module>
#       1 # Test your function
# ----> 2 w2_unittest.test_get_words_by_threshold(get_words_by_threshold, freqs)
#
# ~/work/w2_unittest.py in test_get_words_by_threshold(target, freqs)
#     786                             "name": test_case["name"],
#     787                             "expected": {key: {sec_key: sec_value}},
# --> 788                             "got": {key: result[key][sec_key]},
#     789                         }
#     790                     )
#
# KeyError: 'followfriday'

# %% [markdown]
# <a name='5'></a>
# ## 5 - Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the missclassifications happened? Were there any assumptions made by your naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :D'
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'sr financi analyst expedia inc bellevu wa financ expediajob job job hire'

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict with your own Tweet
#
# In this part you can predict the sentiment of your own tweet.

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 9.571143871339594

# %% [markdown]
# Congratulations on completing this assignment. See you next week!
